# %% [markdown]
# <a href="https://colab.research.google.com/github/aaronkr-classroom/1-car-simulation-busdriver-ko/blob/master/2115203KNY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = "Aaron"
print(f"Hello {name}")
# Out:
# Hello Aaron

# %%
#라이브러리 불러오기
import numpy as np
import matplotlib.pyplot as plt
import math

# %%
#수학 sin 표를 그려보기
time = np.linspace(
    start=0,
    stop = 2*math.pi,
    num=100,
    dtype = np.float32
)
y = np.sin(time)

# %%
plt.figure()
plt.plot(time,y)
plt.xlabel("time")
plt.ylabel("signal")
plt.show()

# %%
x, y, scale = np.random.randn(3, 100)# 3차원 100개

fig, ax = plt.subplots()
ax.scatter(x = x, y = y, c=scale, cmap=plt.cm.viridis, s=50)

# %%
#youtube 동영상

from IPython.display import YouTubeVideo
YouTubeVideo("50kW30jZJPs", 560, 315, rel = 0)

# %% [markdown]
# #practies
#
# hello world!<br>
# My name is Namyoung Kim.<br>
# I like cars.
#
# ---
#
#   | Movies | Year | Actors|
#
#
# ---
#
#
# 1. Pizza
#   - **Papa John's**
#   - _Pizza Hut_
#   - [Domino's](https://dominos.co.kr)
# 2. BBB
# 3. SGS
# 4. BDJG
#
# ![Aaron](https://avatars.githubusercontent.com/u/6644259?v=4)
